# %% [markdown]
# <a href="https://colab.research.google.com/github/YakupTopaloglu/ML_TEST/blob/main/Machine_failure_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import drive
drive.mount('/content/drive/MyDrive/Datasets/factory-equipment-predictive-failure-logs.csv')

# %% [markdown]
# DATASET

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('/content/drive/MyDrive/Datasets/factory-equipment-predictive-failure-logs.csv')
df.head()
# Out:
#          log_id equipment_id   equipment_type                    location  \
# 0     LOG-1023A        EQ001      CNC Machine   Plant A - Machining Bay 1
# 1  LOG-CRIT-821        EQ002  Hydraulic Press  Plant B - Pressing Section
# 2     LOG-2334B        EQ003    Conveyor Belt   Plant A - Assembly Line 3
# 3  LOG-EDGE-001        EQ004   Air Compressor      Plant C - Utility Area
# 4     LOG-4041C        EQ001      CNC Machine   Plant A - Machining Bay 2
#
#    failure_predicted predicted_failure_type predicted_failure_severity  \
# 0               True             mechanical                   critical
# 1               True             mechanical                   critical
# 2               True             electrical                   moderate
# 3              False                    NaN                        NaN
# 4              False                    NaN                        NaN
#
#   predicted_failure_datetime current_status last_maintenance_date  \
# ...

# %%
print(f"The dataset has {df.shape[0]} rows and {df.shape[1]} columns")
print(f"there are {df.isnull().sum()} null values in the dataset")
# Out:
# The dataset has 120 rows and 18 columns
# there are log_id                                     0
# equipment_id                               0
# equipment_type                             0
# location                                   0
# failure_predicted                          0
# predicted_failure_type                    46
# predicted_failure_severity                46
# predicted_failure_datetime                46
# current_status                             0
# last_maintenance_date                     11
# operating_hours_since_last_maintenance     9
# sensor_temperature                        11
# sensor_vibration                          11
# sensor_pressure                           38
# failure_probability                       46
# recommended_action                        46
# action_due_date                           46
# notes                                      0
# dtype: int64 null values in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 18 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   log_id                                  120 non-null    object
#  1   equipment_id                            120 non-null    object
#  2   equipment_type                          120 non-null    object
#  3   location                                120 non-null    object
#  4   failure_predicted                       120 non-null    bool
#  5   predicted_failure_type                  74 non-null     object
#  6   predicted_failure_severity              74 non-null     object
#  7   predicted_failure_datetime              74 non-null     object
#  8   current_status                          120 non-null    object
#  9   last_maintenance_date                   109 non-null    object
# ...
